# %% [markdown]
# # Install Process Mining for Python (pm4py) and Dependencies
#
# This seems to work in SageMaker notebook instances.

# %%
# !conda install -c conda-forge cvxopt "numpy<2" -y

# %%
# !pip install pm4py

# %% [markdown]
# ## Test I can use pm4py
# Try an import

# %%
import cvxopt
from cvxopt import glpk
import pm4py
print("Success! Environment is ready.")
# Out:
# Success! Environment is ready.
